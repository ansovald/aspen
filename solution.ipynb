# %%
from call_clingo import generate_models
from model_handling import print_moves

for disks in range(3, 5):
    print(f"Generating models for {disks} disks:")
    models, time = generate_models(disks=disks)
    for model in models:
        print_moves(model)
    print(f"Time taken: {time['total_time']:.4f} seconds for {disks} disks")
    print("\n\n\n")
# Out:
# Generating models for 3 disks:
# Grounding for 3 disks completed in 0.0026 seconds.
# Solving for 3 disks completed in 0.0013 seconds.
# Total time for 3 disks: 0.0040 seconds.
# 0
# A: [3, 2, 1]
# B: []
# C: []
# 1
# A: [3, 2]
# B: []
# C: [1]
# 2
# A: [3]
# B: [2]
# C: [1]
# 3
# A: [3]
# B: [2, 1]
# C: []
# 4
# A: []
# B: [2, 1]
# C: [3]
# 5
# A: [1]
# B: [2]
# C: [3]
# 6
# A: [1]
# B: []
# C: [3, 2]
# 7
# A: []
# B: []
# C: [3, 2, 1]
#
#
#
#
# Generating models for 4 disks:
# Grounding for 4 disks completed in 0.0035 seconds.
# Solving for 4 disks completed in 0.0131 seconds.
# Total time for 4 disks: 0.0166 seconds.
# 0
# A: [4, 3, 2, 1]
# B: []
# C: []
# 1
# A: [4, 3, 2]
# B: [1]
# C: []
# 2
# A: [4, 3]
# B: [1]
# C: [2]
# 3
# A: [4, 3]
# B: []
# C: [2, 1]
# 4
# A: [4]
# B: [3]
# C: [2, 1]
# 5
# A: [4, 1]
# B: [3]
# C: [2]
# 6
# A: [4, 1]
# B: [3, 2]
# C: []
# 7
# A: [4]
# B: [3, 2, 1]
# C: []
# 8
# A: []
# B: [3, 2, 1]
# C: [4]
# 9
# A: []
# B: [3, 2]
# C: [4, 1]
# 10
# A: [2]
# B: [3]
# C: [4, 1]
# 11
# A: [2, 1]
# B: [3]
# C: [4]
# 12
# A: [2, 1]
# B: []
# C: [4, 3]
# 13
# A: [2]
# B: [1]
# C: [4, 3]
# 14
# A: []
# B: [1]
# C: [4, 3, 2]
# 15
# A: []
# B: []
# C: [4, 3, 2, 1]
#
#
#
#
# Generating models for 5 disks:
# Grounding for 5 disks completed in 0.0055 seconds.
# Solving for 5 disks completed in 0.0667 seconds.
# Total time for 5 disks: 0.0723 seconds.
# 0
# A: [5, 4, 3, 2, 1]
# B: []
# C: []
# 1
# A: [5, 4, 3, 2]
# B: []
# C: [1]
# 2
# A: [5, 4, 3]
# B: [2]
# C: [1]
# 3
# A: [5, 4, 3]
# B: [2, 1]
# C: []
# 4
# A: [5, 4]
# B: [2, 1]
# C: [3]
# 5
# A: [5, 4, 1]
# B: [2]
# C: [3]
# 6
# A: [5, 4, 1]
# B: []
# C: [3, 2]
# 7
# A: [5, 4]
# B: []
# C: [3, 2, 1]
# 8
# A: [5]
# B: [4]
# C: [3, 2, 1]
# 9
# A: [5]
# B: [4, 1]
# C: [3, 2]
# 10
# A: [5, 2]
# B: [4, 1]
# C: [3]
# 11
# A: [5, 2, 1]
# B: [4]
# C: [3]
# 12
# A: [5, 2, 1]
# B: [4, 3]
# C: []
# 13
# A: [5, 2]
# B: [4, 3]
# C: [1]
# 14
# A: [5]
# B: [4, 3, 2]
# C: [1]
# 15
# A: [5]
# B: [4, 3, 2, 1]
# C: []
# 16
# A: []
# B: [4, 3, 2, 1]
# C: [5]
# 17
# A: [1]
# B: [4, 3, 2]
# C: [5]
# 18
# A: [1]
# B: [4, 3]
# C: [5, 2]
# 19
# A: []
# B: [4, 3]
# C: [5, 2, 1]
# 20
# A: [3]
# B: [4]
# C: [5, 2, 1]
# 21
# A: [3]
# B: [4, 1]
# C: [5, 2]
# 22
# A: [3, 2]
# B: [4, 1]
# C: [5]
# 23
# A: [3, 2, 1]
# B: [4]
# C: [5]
# 24
# A: [3, 2, 1]
# B: []
# C: [5, 4]
# 25
# A: [3, 2]
# B: []
# C: [5, 4, 1]
# 26
# A: [3]
# B: [2]
# C: [5, 4, 1]
# 27
# A: [3]
# B: [2, 1]
# C: [5, 4]
# 28
# A: []
# B: [2, 1]
# C: [5, 4, 3]
# 29
# A: [1]
# B: [2]
# C: [5, 4, 3]
# 30
# A: [1]
# B: []
# C: [5, 4, 3, 2]
# 31
# A: []
# B: []
# C: [5, 4, 3, 2, 1]
#
#
#
#
# Generating models for 6 disks:
# Grounding for 6 disks completed in 0.0094 seconds.
# Solving for 6 disks completed in 0.4149 seconds.
# Total time for 6 disks: 0.4245 seconds.
# 0
# A: [6, 5, 4, 3, 2, 1]
# B: []
# C: []
# 1
# A: [6, 5, 4, 3, 2]
# B: [1]
# C: []
# 2
# A: [6, 5, 4, 3]
# B: [1]
# C: [2]
# 3
# A: [6, 5, 4, 3]
# B: []
# C: [2, 1]
# 4
# A: [6, 5, 4]
# B: [3]
# C: [2, 1]
# 5
# A: [6, 5, 4, 1]
# B: [3]
# C: [2]
# 6
# A: [6, 5, 4, 1]
# B: [3, 2]
# C: []
# 7
# A: [6, 5, 4]
# B: [3, 2, 1]
# C: []
# 8
# A: [6, 5]
# B: [3, 2, 1]
# C: [4]
# 9
# A: [6, 5]
# B: [3, 2]
# C: [4, 1]
# 10
# A: [6, 5, 2]
# B: [3]
# C: [4, 1]
# 11
# A: [6, 5, 2, 1]
# B: [3]
# C: [4]
# 12
# A: [6, 5, 2, 1]
# B: []
# C: [4, 3]
# 13
# A: [6, 5, 2]
# B: [1]
# C: [4, 3]
# 14
# A: [6, 5]
# B: [1]
# C: [4, 3, 2]
# 15
# A: [6, 5]
# B: []
# C: [4, 3, 2, 1]
# 16
# A: [6]
# B: [5]
# C: [4, 3, 2, 1]
# 17
# A: [6, 1]
# B: [5]
# C: [4, 3, 2]
# 18
# A: [6, 1]
# B: [5, 2]
# C: [4, 3]
# 19
# A: [6]
# B: [5, 2, 1]
# C: [4, 3]
# 20
# A: [6, 3]
# B: [5, 2, 1]
# C: [4]
# 21
# A: [6, 3]
# B: [5, 2]
# C: [4, 1]
# 22
# A: [6, 3, 2]
# B: [5]
# C: [4, 1]
# 23
# A: [6, 3, 2, 1]
# B: [5]
# C: [4]
# 24
# A: [6, 3, 2, 1]
# B: [5, 4]
# C: []
# 25
# A: [6, 3, 2]
# B: [5, 4, 1]
# C: []
# 26
# A: [6, 3]
# B: [5, 4, 1]
# C: [2]
# 27
# A: [6, 3]
# B: [5, 4]
# C: [2, 1]
# 28
# A: [6]
# B: [5, 4, 3]
# C: [2, 1]
# 29
# A: [6, 1]
# B: [5, 4, 3]
# C: [2]
# 30
# A: [6, 1]
# B: [5, 4, 3, 2]
# C: []
# 31
# A: [6]
# B: [5, 4, 3, 2, 1]
# C: []
# 32
# A: []
# B: [5, 4, 3, 2, 1]
# C: [6]
# 33
# A: []
# B: [5, 4, 3, 2]
# C: [6, 1]
# 34
# A: [2]
# B: [5, 4, 3]
# C: [6, 1]
# 35
# A: [2, 1]
# B: [5, 4, 3]
# C: [6]
# 36
# A: [2, 1]
# B: [5, 4]
# C: [6, 3]
# 37
# A: [2]
# B: [5, 4, 1]
# C: [6, 3]
# 38
# A: []
# B: [5, 4, 1]
# C: [6, 3, 2]
# 39
# A: []
# B: [5, 4]
# C: [6, 3, 2, 1]
# 40
# A: [4]
# B: [5]
# C: [6, 3, 2, 1]
# 41
# A: [4, 1]
# B: [5]
# C: [6, 3, 2]
# 42
# A: [4, 1]
# B: [5, 2]
# C: [6, 3]
# 43
# A: [4]
# B: [5, 2, 1]
# C: [6, 3]
# 44
# A: [4, 3]
# B: [5, 2, 1]
# C: [6]
# 45
# A: [4, 3]
# B: [5, 2]
# C: [6, 1]
# 46
# A: [4, 3, 2]
# B: [5]
# C: [6, 1]
# 47
# A: [4, 3, 2, 1]
# B: [5]
# C: [6]
# 48
# A: [4, 3, 2, 1]
# B: []
# C: [6, 5]
# 49
# A: [4, 3, 2]
# B: [1]
# C: [6, 5]
# 50
# A: [4, 3]
# B: [1]
# C: [6, 5, 2]
# 51
# A: [4, 3]
# B: []
# C: [6, 5, 2, 1]
# 52
# A: [4]
# B: [3]
# C: [6, 5, 2, 1]
# 53
# A: [4, 1]
# B: [3]
# C: [6, 5, 2]
# 54
# A: [4, 1]
# B: [3, 2]
# C: [6, 5]
# 55
# A: [4]
# B: [3, 2, 1]
# C: [6, 5]
# 56
# A: []
# B: [3, 2, 1]
# C: [6, 5, 4]
# 57
# A: []
# B: [3, 2]
# C: [6, 5, 4, 1]
# 58
# A: [2]
# B: [3]
# C: [6, 5, 4, 1]
# 59
# A: [2, 1]
# B: [3]
# C: [6, 5, 4]
# 60
# A: [2, 1]
# B: []
# C: [6, 5, 4, 3]
# 61
# A: [2]
# B: [1]
# C: [6, 5, 4, 3]
# 62
# A: []
# B: [1]
# C: [6, 5, 4, 3, 2]
# 63
# A: []
# B: []
# C: [6, 5, 4, 3, 2, 1]
#
#
#
#
# Generating models for 7 disks:
# Grounding for 7 disks completed in 0.0227 seconds.
# Solving for 7 disks completed in 8.7862 seconds.
# Total time for 7 disks: 8.8090 seconds.
# 0
# A: [7, 6, 5, 4, 3, 2, 1]
# B: []
# C: []
# 1
# A: [7, 6, 5, 4, 3, 2]
# B: []
# C: [1]
# 2
# A: [7, 6, 5, 4, 3]
# B: [2]
# C: [1]
# 3
# A: [7, 6, 5, 4, 3]
# B: [2, 1]
# C: []
# 4
# A: [7, 6, 5, 4]
# B: [2, 1]
# C: [3]
# 5
# A: [7, 6, 5, 4, 1]
# B: [2]
# C: [3]
# 6
# A: [7, 6, 5, 4, 1]
# B: []
# C: [3, 2]
# 7
# A: [7, 6, 5, 4]
# B: []
# C: [3, 2, 1]
# 8
# A: [7, 6, 5]
# B: [4]
# C: [3, 2, 1]
# 9
# A: [7, 6, 5]
# B: [4, 1]
# C: [3, 2]
# 10
# A: [7, 6, 5, 2]
# B: [4, 1]
# C: [3]
# 11
# A: [7, 6, 5, 2, 1]
# B: [4]
# C: [3]
# 12
# A: [7, 6, 5, 2, 1]
# B: [4, 3]
# C: []
# 13
# A: [7, 6, 5, 2]
# B: [4, 3]
# C: [1]
# 14
# A: [7, 6, 5]
# B: [4, 3, 2]
# C: [1]
# 15
# A: [7, 6, 5]
# B: [4, 3, 2, 1]
# C: []
# 16
# A: [7, 6]
# B: [4, 3, 2, 1]
# C: [5]
# 17
# A: [7, 6, 1]
# B: [4, 3, 2]
# C: [5]
# 18
# A: [7, 6, 1]
# B: [4, 3]
# C: [5, 2]
# 19
# A: [7, 6]
# B: [4, 3]
# C: [5, 2, 1]
# 20
# A: [7, 6, 3]
# B: [4]
# C: [5, 2, 1]
# 21
# A: [7, 6, 3]
# B: [4, 1]
# C: [5, 2]
# 22
# A: [7, 6, 3, 2]
# B: [4, 1]
# C: [5]
# 23
# A: [7, 6, 3, 2, 1]
# B: [4]
# C: [5]
# 24
# A: [7, 6, 3, 2, 1]
# B: []
# C: [5, 4]
# 25
# A: [7, 6, 3, 2]
# B: []
# C: [5, 4, 1]
# 26
# A: [7, 6, 3]
# B: [2]
# C: [5, 4, 1]
# 27
# A: [7, 6, 3]
# B: [2, 1]
# C: [5, 4]
# 28
# A: [7, 6]
# B: [2, 1]
# C: [5, 4, 3]
# 29
# A: [7, 6, 1]
# B: [2]
# C: [5, 4, 3]
# 30
# A: [7, 6, 1]
# B: []
# C: [5, 4, 3, 2]
# 31
# A: [7, 6]
# B: []
# C: [5, 4, 3, 2, 1]
# 32
# A: [7]
# B: [6]
# C: [5, 4, 3, 2, 1]
# 33
# A: [7]
# B: [6, 1]
# C: [5, 4, 3, 2]
# 34
# A: [7, 2]
# B: [6, 1]
# C: [5, 4, 3]
# 35
# A: [7, 2, 1]
# B: [6]
# C: [5, 4, 3]
# 36
# A: [7, 2, 1]
# B: [6, 3]
# C: [5, 4]
# 37
# A: [7, 2]
# B: [6, 3]
# C: [5, 4, 1]
# 38
# A: [7]
# B: [6, 3, 2]
# C: [5, 4, 1]
# 39
# A: [7]
# B: [6, 3, 2, 1]
# C: [5, 4]
# 40
# A: [7, 4]
# B: [6, 3, 2, 1]
# C: [5]
# 41
# A: [7, 4, 1]
# B: [6, 3, 2]
# C: [5]
# 42
# A: [7, 4, 1]
# B: [6, 3]
# C: [5, 2]
# 43
# A: [7, 4]
# B: [6, 3]
# C: [5, 2, 1]
# 44
# A: [7, 4, 3]
# B: [6]
# C: [5, 2, 1]
# 45
# A: [7, 4, 3]
# B: [6, 1]
# C: [5, 2]
# 46
# A: [7, 4, 3, 2]
# B: [6, 1]
# C: [5]
# 47
# A: [7, 4, 3, 2, 1]
# B: [6]
# C: [5]
# 48
# A: [7, 4, 3, 2, 1]
# B: [6, 5]
# C: []
# 49
# A: [7, 4, 3, 2]
# B: [6, 5]
# C: [1]
# 50
# A: [7, 4, 3]
# B: [6, 5, 2]
# C: [1]
# 51
# A: [7, 4, 3]
# B: [6, 5, 2, 1]
# C: []
# 52
# A: [7, 4]
# B: [6, 5, 2, 1]
# C: [3]
# 53
# A: [7, 4, 1]
# B: [6, 5, 2]
# C: [3]
# 54
# A: [7, 4, 1]
# B: [6, 5]
# C: [3, 2]
# 55
# A: [7, 4]
# B: [6, 5]
# C: [3, 2, 1]
# 56
# A: [7]
# B: [6, 5, 4]
# C: [3, 2, 1]
# 57
# A: [7]
# B: [6, 5, 4, 1]
# C: [3, 2]
# 58
# A: [7, 2]
# B: [6, 5, 4, 1]
# C: [3]
# 59
# A: [7, 2, 1]
# B: [6, 5, 4]
# C: [3]
# 60
# A: [7, 2, 1]
# B: [6, 5, 4, 3]
# C: []
# 61
# A: [7, 2]
# B: [6, 5, 4, 3]
# C: [1]
# 62
# A: [7]
# B: [6, 5, 4, 3, 2]
# C: [1]
# 63
# A: [7]
# B: [6, 5, 4, 3, 2, 1]
# C: []
# 64
# A: []
# B: [6, 5, 4, 3, 2, 1]
# C: [7]
# 65
# A: [1]
# B: [6, 5, 4, 3, 2]
# C: [7]
# 66
# A: [1]
# B: [6, 5, 4, 3]
# C: [7, 2]
# 67
# A: []
# B: [6, 5, 4, 3]
# C: [7, 2, 1]
# 68
# A: [3]
# B: [6, 5, 4]
# C: [7, 2, 1]
# 69
# A: [3]
# B: [6, 5, 4, 1]
# C: [7, 2]
# 70
# A: [3, 2]
# B: [6, 5, 4, 1]
# C: [7]
# 71
# A: [3, 2, 1]
# B: [6, 5, 4]
# C: [7]
# 72
# A: [3, 2, 1]
# B: [6, 5]
# C: [7, 4]
# 73
# A: [3, 2]
# B: [6, 5]
# C: [7, 4, 1]
# 74
# A: [3]
# B: [6, 5, 2]
# C: [7, 4, 1]
# 75
# A: [3]
# B: [6, 5, 2, 1]
# C: [7, 4]
# 76
# A: []
# B: [6, 5, 2, 1]
# C: [7, 4, 3]
# 77
# A: [1]
# B: [6, 5, 2]
# C: [7, 4, 3]
# 78
# A: [1]
# B: [6, 5]
# C: [7, 4, 3, 2]
# 79
# A: []
# B: [6, 5]
# C: [7, 4, 3, 2, 1]
# 80
# A: [5]
# B: [6]
# C: [7, 4, 3, 2, 1]
# 81
# A: [5]
# B: [6, 1]
# C: [7, 4, 3, 2]
# 82
# A: [5, 2]
# B: [6, 1]
# C: [7, 4, 3]
# 83
# A: [5, 2, 1]
# B: [6]
# C: [7, 4, 3]
# 84
# A: [5, 2, 1]
# B: [6, 3]
# C: [7, 4]
# 85
# A: [5, 2]
# B: [6, 3]
# C: [7, 4, 1]
# 86
# A: [5]
# B: [6, 3, 2]
# C: [7, 4, 1]
# 87
# A: [5]
# B: [6, 3, 2, 1]
# C: [7, 4]
# 88
# A: [5, 4]
# B: [6, 3, 2, 1]
# C: [7]
# 89
# A: [5, 4, 1]
# B: [6, 3, 2]
# C: [7]
# 90
# A: [5, 4, 1]
# B: [6, 3]
# C: [7, 2]
# 91
# A: [5, 4]
# B: [6, 3]
# C: [7, 2, 1]
# 92
# A: [5, 4, 3]
# B: [6]
# C: [7, 2, 1]
# 93
# A: [5, 4, 3]
# B: [6, 1]
# C: [7, 2]
# 94
# A: [5, 4, 3, 2]
# B: [6, 1]
# C: [7]
# 95
# A: [5, 4, 3, 2, 1]
# B: [6]
# C: [7]
# 96
# A: [5, 4, 3, 2, 1]
# B: []
# C: [7, 6]
# 97
# A: [5, 4, 3, 2]
# B: []
# C: [7, 6, 1]
# 98
# A: [5, 4, 3]
# B: [2]
# C: [7, 6, 1]
# 99
# A: [5, 4, 3]
# B: [2, 1]
# C: [7, 6]
# 100
# A: [5, 4]
# B: [2, 1]
# C: [7, 6, 3]
# 101
# A: [5, 4, 1]
# B: [2]
# C: [7, 6, 3]
# 102
# A: [5, 4, 1]
# B: []
# C: [7, 6, 3, 2]
# 103
# A: [5, 4]
# B: []
# C: [7, 6, 3, 2, 1]
# 104
# A: [5]
# B: [4]
# C: [7, 6, 3, 2, 1]
# 105
# A: [5]
# B: [4, 1]
# C: [7, 6, 3, 2]
# 106
# A: [5, 2]
# B: [4, 1]
# C: [7, 6, 3]
# 107
# A: [5, 2, 1]
# B: [4]
# C: [7, 6, 3]
# 108
# A: [5, 2, 1]
# B: [4, 3]
# C: [7, 6]
# 109
# A: [5, 2]
# B: [4, 3]
# C: [7, 6, 1]
# 110
# A: [5]
# B: [4, 3, 2]
# C: [7, 6, 1]
# 111
# A: [5]
# B: [4, 3, 2, 1]
# C: [7, 6]
# 112
# A: []
# B: [4, 3, 2, 1]
# C: [7, 6, 5]
# 113
# A: [1]
# B: [4, 3, 2]
# C: [7, 6, 5]
# 114
# A: [1]
# B: [4, 3]
# C: [7, 6, 5, 2]
# 115
# A: []
# B: [4, 3]
# C: [7, 6, 5, 2, 1]
# 116
# A: [3]
# B: [4]
# C: [7, 6, 5, 2, 1]
# 117
# A: [3]
# B: [4, 1]
# C: [7, 6, 5, 2]
# 118
# A: [3, 2]
# B: [4, 1]
# C: [7, 6, 5]
# 119
# A: [3, 2, 1]
# B: [4]
# C: [7, 6, 5]
# 120
# A: [3, 2, 1]
# B: []
# C: [7, 6, 5, 4]
# 121
# A: [3, 2]
# B: []
# C: [7, 6, 5, 4, 1]
# 122
# A: [3]
# B: [2]
# C: [7, 6, 5, 4, 1]
# 123
# A: [3]
# B: [2, 1]
# C: [7, 6, 5, 4]
# 124
# A: []
# B: [2, 1]
# C: [7, 6, 5, 4, 3]
# 125
# A: [1]
# B: [2]
# C: [7, 6, 5, 4, 3]
# 126
# A: [1]
# B: []
# C: [7, 6, 5, 4, 3, 2]
# 127
# A: []
# B: []
# C: [7, 6, 5, 4, 3, 2, 1]
#
#
#
#
# Generating models for 8 disks:
# Grounding for 8 disks completed in 0.0539 seconds.
# Solving for 8 disks completed in 60.0001 seconds.
# Total time for 8 disks: 60.0541 seconds.
# 0
# A: [8, 7, 6, 5, 4, 3, 2, 1]
# B: []
# C: []
# 1
# A: [8, 7, 6, 5, 4, 3, 2]
# B: [1]
# C: []
# 2
# A: [8, 7, 6, 5, 4, 3]
# B: [1]
# C: [2]
# 3
# A: [8, 7, 6, 5, 4, 3]
# B: []
# C: [2, 1]
# 4
# A: [8, 7, 6, 5, 4]
# B: [3]
# C: [2, 1]
# 5
# A: [8, 7, 6, 5, 4, 1]
# B: [3]
# C: [2]
# 6
# A: [8, 7, 6, 5, 4, 1]
# B: [3, 2]
# C: []
# 7
# A: [8, 7, 6, 5, 4]
# B: [3, 2, 1]
# C: []
# 8
# A: [8, 7, 6, 5]
# B: [3, 2, 1]
# C: [4]
# 9
# A: [8, 7, 6, 5]
# B: [3, 2]
# C: [4, 1]
# 10
# A: [8, 7, 6, 5, 2]
# B: [3]
# C: [4, 1]
# 11
# A: [8, 7, 6, 5, 2, 1]
# B: [3]
# C: [4]
# 12
# A: [8, 7, 6, 5, 2, 1]
# B: []
# C: [4, 3]
# 13
# A: [8, 7, 6, 5, 2]
# B: [1]
# C: [4, 3]
# 14
# A: [8, 7, 6, 5]
# B: [1]
# C: [4, 3, 2]
# 15
# A: [8, 7, 6, 5]
# B: []
# C: [4, 3, 2, 1]
# 16
# A: [8, 7, 6]
# B: [5]
# C: [4, 3, 2, 1]
# 17
# A: [8, 7, 6, 1]
# B: [5]
# C: [4, 3, 2]
# 18
# A: [8, 7, 6, 1]
# B: [5, 2]
# C: [4, 3]
# 19
# A: [8, 7, 6]
# B: [5, 2, 1]
# C: [4, 3]
# 20
# A: [8, 7, 6, 3]
# B: [5, 2, 1]
# C: [4]
# 21
# A: [8, 7, 6, 3]
# B: [5, 2]
# C: [4, 1]
# 22
# A: [8, 7, 6, 3, 2]
# B: [5]
# C: [4, 1]
# 23
# A: [8, 7, 6, 3, 2, 1]
# B: [5]
# C: [4]
# 24
# A: [8, 7, 6, 3, 2, 1]
# B: [5, 4]
# C: []
# 25
# A: [8, 7, 6, 3, 2]
# B: [5, 4, 1]
# C: []
# 26
# A: [8, 7, 6, 3]
# B: [5, 4, 1]
# C: [2]
# 27
# A: [8, 7, 6, 3]
# B: [5, 4]
# C: [2, 1]
# 28
# A: [8, 7, 6]
# B: [5, 4, 3]
# C: [2, 1]
# 29
# A: [8, 7, 6, 1]
# B: [5, 4, 3]
# C: [2]
# 30
# A: [8, 7, 6, 1]
# B: [5, 4, 3, 2]
# C: []
# 31
# A: [8, 7, 6]
# B: [5, 4, 3, 2, 1]
# C: []
# 32
# A: [8, 7]
# B: [5, 4, 3, 2, 1]
# C: [6]
# 33
# A: [8, 7]
# B: [5, 4, 3, 2]
# C: [6, 1]
# 34
# A: [8, 7, 2]
# B: [5, 4, 3]
# C: [6, 1]
# 35
# A: [8, 7, 2, 1]
# B: [5, 4, 3]
# C: [6]
# 36
# A: [8, 7, 2, 1]
# B: [5, 4]
# C: [6, 3]
# 37
# A: [8, 7, 2]
# B: [5, 4, 1]
# C: [6, 3]
# 38
# A: [8, 7]
# B: [5, 4, 1]
# C: [6, 3, 2]
# 39
# A: [8, 7]
# B: [5, 4]
# C: [6, 3, 2, 1]
# 40
# A: [8, 7, 4]
# B: [5]
# C: [6, 3, 2, 1]
# 41
# A: [8, 7, 4, 1]
# B: [5]
# C: [6, 3, 2]
# 42
# A: [8, 7, 4, 1]
# B: [5, 2]
# C: [6, 3]
# 43
# A: [8, 7, 4]
# B: [5, 2, 1]
# C: [6, 3]
# 44
# A: [8, 7, 4, 3]
# B: [5, 2, 1]
# C: [6]
# 45
# A: [8, 7, 4, 3]
# B: [5, 2]
# C: [6, 1]
# 46
# A: [8, 7, 4, 3, 2]
# B: [5]
# C: [6, 1]
# 47
# A: [8, 7, 4, 3, 2, 1]
# B: [5]
# C: [6]
# 48
# A: [8, 7, 4, 3, 2, 1]
# B: []
# C: [6, 5]
# 49
# A: [8, 7, 4, 3, 2]
# B: [1]
# C: [6, 5]
# 50
# A: [8, 7, 4, 3]
# B: [1]
# C: [6, 5, 2]
# 51
# A: [8, 7, 4, 3]
# B: []
# C: [6, 5, 2, 1]
# 52
# A: [8, 7, 4]
# B: [3]
# C: [6, 5, 2, 1]
# 53
# A: [8, 7, 4, 1]
# B: [3]
# C: [6, 5, 2]
# 54
# A: [8, 7, 4, 1]
# B: [3, 2]
# C: [6, 5]
# 55
# A: [8, 7, 4]
# B: [3, 2, 1]
# C: [6, 5]
# 56
# A: [8, 7]
# B: [3, 2, 1]
# C: [6, 5, 4]
# 57
# A: [8, 7]
# B: [3, 2]
# C: [6, 5, 4, 1]
# 58
# A: [8, 7, 2]
# B: [3]
# C: [6, 5, 4, 1]
# 59
# A: [8, 7, 2, 1]
# B: [3]
# C: [6, 5, 4]
# 60
# A: [8, 7, 2, 1]
# B: []
# C: [6, 5, 4, 3]
# 61
# A: [8, 7, 2]
# B: [1]
# C: [6, 5, 4, 3]
# 62
# A: [8, 7]
# B: [1]
# C: [6, 5, 4, 3, 2]
# 63
# A: [8, 7]
# B: []
# C: [6, 5, 4, 3, 2, 1]
# 64
# A: [8]
# B: [7]
# C: [6, 5, 4, 3, 2, 1]
# 65
# A: [8, 1]
# B: [7]
# C: [6, 5, 4, 3, 2]
# 66
# A: [8, 1]
# B: [7, 2]
# C: [6, 5, 4, 3]
# 67
# A: [8]
# B: [7, 2, 1]
# C: [6, 5, 4, 3]
# 68
# A: [8, 3]
# B: [7, 2, 1]
# C: [6, 5, 4]
# 69
# A: [8, 3]
# B: [7, 2]
# C: [6, 5, 4, 1]
# 70
# A: [8, 3, 2]
# B: [7]
# C: [6, 5, 4, 1]
# 71
# A: [8, 3, 2, 1]
# B: [7]
# C: [6, 5, 4]
# 72
# A: [8, 3, 2, 1]
# B: [7, 4]
# C: [6, 5]
# 73
# A: [8, 3, 2]
# B: [7, 4, 1]
# C: [6, 5]
# 74
# A: [8, 3]
# B: [7, 4, 1]
# C: [6, 5, 2]
# 75
# A: [8, 3]
# B: [7, 4]
# C: [6, 5, 2, 1]
# 76
# A: [8]
# B: [7, 4, 3]
# C: [6, 5, 2, 1]
# 77
# A: [8, 1]
# B: [7, 4, 3]
# C: [6, 5, 2]
# 78
# A: [8, 1]
# B: [7, 4, 3, 2]
# C: [6, 5]
# 79
# A: [8]
# B: [7, 4, 3, 2, 1]
# C: [6, 5]
# 80
# A: [8, 5]
# B: [7, 4, 3, 2, 1]
# C: [6]
# 81
# A: [8, 5]
# B: [7, 4, 3, 2]
# C: [6, 1]
# 82
# A: [8, 5, 2]
# B: [7, 4, 3]
# C: [6, 1]
# 83
# A: [8, 5, 2, 1]
# B: [7, 4, 3]
# C: [6]
# 84
# A: [8, 5, 2, 1]
# B: [7, 4]
# C: [6, 3]
# 85
# A: [8, 5, 2]
# B: [7, 4, 1]
# C: [6, 3]
# 86
# A: [8, 5]
# B: [7, 4, 1]
# C: [6, 3, 2]
# 87
# A: [8, 5]
# B: [7, 4]
# C: [6, 3, 2, 1]
# 88
# A: [8, 5, 4]
# B: [7]
# C: [6, 3, 2, 1]
# 89
# A: [8, 5, 4, 1]
# B: [7]
# C: [6, 3, 2]
# 90
# A: [8, 5, 4, 1]
# B: [7, 2]
# C: [6, 3]
# 91
# A: [8, 5, 4]
# B: [7, 2, 1]
# C: [6, 3]
# 92
# A: [8, 5, 4, 3]
# B: [7, 2, 1]
# C: [6]
# 93
# A: [8, 5, 4, 3]
# B: [7, 2]
# C: [6, 1]
# 94
# A: [8, 5, 4, 3, 2]
# B: [7]
# C: [6, 1]
# 95
# A: [8, 5, 4, 3, 2, 1]
# B: [7]
# C: [6]
# 96
# A: [8, 5, 4, 3, 2, 1]
# B: [7, 6]
# C: []
# 97
# A: [8, 5, 4, 3, 2]
# B: [7, 6, 1]
# C: []
# 98
# A: [8, 5, 4, 3]
# B: [7, 6, 1]
# C: [2]
# 99
# A: [8, 5, 4, 3]
# B: [7, 6]
# C: [2, 1]
# 100
# A: [8, 5, 4]
# B: [7, 6, 3]
# C: [2, 1]
# 101
# A: [8, 5, 4, 1]
# B: [7, 6, 3]
# C: [2]
# 102
# A: [8, 5, 4, 1]
# B: [7, 6, 3, 2]
# C: []
# 103
# A: [8, 5, 4]
# B: [7, 6, 3, 2, 1]
# C: []
# 104
# A: [8, 5]
# B: [7, 6, 3, 2, 1]
# C: [4]
# 105
# A: [8, 5]
# B: [7, 6, 3, 2]
# C: [4, 1]
# 106
# A: [8, 5, 2]
# B: [7, 6, 3]
# C: [4, 1]
# 107
# A: [8, 5, 2, 1]
# B: [7, 6, 3]
# C: [4]
# 108
# A: [8, 5, 2, 1]
# B: [7, 6]
# C: [4, 3]
# 109
# A: [8, 5, 2]
# B: [7, 6, 1]
# C: [4, 3]
# 110
# A: [8, 5]
# B: [7, 6, 1]
# C: [4, 3, 2]
# 111
# A: [8, 5]
# B: [7, 6]
# C: [4, 3, 2, 1]
# 112
# A: [8]
# B: [7, 6, 5]
# C: [4, 3, 2, 1]
# 113
# A: [8, 1]
# B: [7, 6, 5]
# C: [4, 3, 2]
# 114
# A: [8, 1]
# B: [7, 6, 5, 2]
# C: [4, 3]
# 115
# A: [8]
# B: [7, 6, 5, 2, 1]
# C: [4, 3]
# 116
# A: [8, 3]
# B: [7, 6, 5, 2, 1]
# C: [4]
# 117
# A: [8, 3]
# B: [7, 6, 5, 2]
# C: [4, 1]
# 118
# A: [8, 3, 2]
# B: [7, 6, 5]
# C: [4, 1]
# 119
# A: [8, 3, 2, 1]
# B: [7, 6, 5]
# C: [4]
# 120
# A: [8, 3, 2, 1]
# B: [7, 6, 5, 4]
# C: []
# 121
# A: [8, 3, 2]
# B: [7, 6, 5, 4, 1]
# C: []
# 122
# A: [8, 3]
# B: [7, 6, 5, 4, 1]
# C: [2]
# 123
# A: [8, 3]
# B: [7, 6, 5, 4]
# C: [2, 1]
# 124
# A: [8]
# B: [7, 6, 5, 4, 3]
# C: [2, 1]
# 125
# A: [8, 1]
# B: [7, 6, 5, 4, 3]
# C: [2]
# 126
# A: [8, 1]
# B: [7, 6, 5, 4, 3, 2]
# C: []
# 127
# A: [8]
# B: [7, 6, 5, 4, 3, 2, 1]
# C: []
# 128
# A: []
# B: [7, 6, 5, 4, 3, 2, 1]
# C: [8]
# 129
# A: []
# B: [7, 6, 5, 4, 3, 2]
# C: [8, 1]
# 130
# A: [2]
# B: [7, 6, 5, 4, 3]
# C: [8, 1]
# 131
# A: [2, 1]
# B: [7, 6, 5, 4, 3]
# C: [8]
# 132
# A: [2, 1]
# B: [7, 6, 5, 4]
# C: [8, 3]
# 133
# A: [2]
# B: [7, 6, 5, 4, 1]
# C: [8, 3]
# 134
# A: []
# B: [7, 6, 5, 4, 1]
# C: [8, 3, 2]
# 135
# A: []
# B: [7, 6, 5, 4]
# C: [8, 3, 2, 1]
# 136
# A: [4]
# B: [7, 6, 5]
# C: [8, 3, 2, 1]
# 137
# A: [4, 1]
# B: [7, 6, 5]
# C: [8, 3, 2]
# 138
# A: [4, 1]
# B: [7, 6, 5, 2]
# C: [8, 3]
# 139
# A: [4]
# B: [7, 6, 5, 2, 1]
# C: [8, 3]
# 140
# A: [4, 3]
# B: [7, 6, 5, 2, 1]
# C: [8]
# 141
# A: [4, 3]
# B: [7, 6, 5, 2]
# C: [8, 1]
# 142
# A: [4, 3, 2]
# B: [7, 6, 5]
# C: [8, 1]
# 143
# A: [4, 3, 2, 1]
# B: [7, 6, 5]
# C: [8]
# 144
# A: [4, 3, 2, 1]
# B: [7, 6]
# C: [8, 5]
# 145
# A: [4, 3, 2]
# B: [7, 6, 1]
# C: [8, 5]
# 146
# A: [4, 3]
# B: [7, 6, 1]
# C: [8, 5, 2]
# 147
# A: [4, 3]
# B: [7, 6]
# C: [8, 5, 2, 1]
# 148
# A: [4]
# B: [7, 6, 3]
# C: [8, 5, 2, 1]
# 149
# A: [4, 1]
# B: [7, 6, 3]
# C: [8, 5, 2]
# 150
# A: [4, 1]
# B: [7, 6, 3, 2]
# C: [8, 5]
# 151
# A: [4]
# B: [7, 6, 3, 2, 1]
# C: [8, 5]
# 152
# A: []
# B: [7, 6, 3, 2, 1]
# C: [8, 5, 4]
# 153
# A: []
# B: [7, 6, 3, 2]
# C: [8, 5, 4, 1]
# 154
# A: [2]
# B: [7, 6, 3]
# C: [8, 5, 4, 1]
# 155
# A: [2, 1]
# B: [7, 6, 3]
# C: [8, 5, 4]
# 156
# A: [2, 1]
# B: [7, 6]
# C: [8, 5, 4, 3]
# 157
# A: [2]
# B: [7, 6, 1]
# C: [8, 5, 4, 3]
# 158
# A: []
# B: [7, 6, 1]
# C: [8, 5, 4, 3, 2]
# 159
# A: []
# B: [7, 6]
# C: [8, 5, 4, 3, 2, 1]
# 160
# A: [6]
# B: [7]
# C: [8, 5, 4, 3, 2, 1]
# 161
# A: [6, 1]
# B: [7]
# C: [8, 5, 4, 3, 2]
# 162
# A: [6, 1]
# B: [7, 2]
# C: [8, 5, 4, 3]
# 163
# A: [6]
# B: [7, 2, 1]
# C: [8, 5, 4, 3]
# 164
# A: [6, 3]
# B: [7, 2, 1]
# C: [8, 5, 4]
# 165
# A: [6, 3]
# B: [7, 2]
# C: [8, 5, 4, 1]
# 166
# A: [6, 3, 2]
# B: [7]
# C: [8, 5, 4, 1]
# 167
# A: [6, 3, 2, 1]
# B: [7]
# C: [8, 5, 4]
# 168
# A: [6, 3, 2, 1]
# B: [7, 4]
# C: [8, 5]
# 169
# A: [6, 3, 2]
# B: [7, 4, 1]
# C: [8, 5]
# 170
# A: [6, 3]
# B: [7, 4, 1]
# C: [8, 5, 2]
# 171
# A: [6, 3]
# B: [7, 4]
# C: [8, 5, 2, 1]
# 172
# A: [6]
# B: [7, 4, 3]
# C: [8, 5, 2, 1]
# 173
# A: [6, 1]
# B: [7, 4, 3]
# C: [8, 5, 2]
# 174
# A: [6, 1]
# B: [7, 4, 3, 2]
# C: [8, 5]
# 175
# A: [6]
# B: [7, 4, 3, 2, 1]
# C: [8, 5]
# 176
# A: [6, 5]
# B: [7, 4, 3, 2, 1]
# C: [8]
# 177
# A: [6, 5]
# B: [7, 4, 3, 2]
# C: [8, 1]
# 178
# A: [6, 5, 2]
# B: [7, 4, 3]
# C: [8, 1]
# 179
# A: [6, 5, 2, 1]
# B: [7, 4, 3]
# C: [8]
# 180
# A: [6, 5, 2, 1]
# B: [7, 4]
# C: [8, 3]
# 181
# A: [6, 5, 2]
# B: [7, 4, 1]
# C: [8, 3]
# 182
# A: [6, 5]
# B: [7, 4, 1]
# C: [8, 3, 2]
# 183
# A: [6, 5]
# B: [7, 4]
# C: [8, 3, 2, 1]
# 184
# A: [6, 5, 4]
# B: [7]
# C: [8, 3, 2, 1]
# 185
# A: [6, 5, 4, 1]
# B: [7]
# C: [8, 3, 2]
# 186
# A: [6, 5, 4, 1]
# B: [7, 2]
# C: [8, 3]
# 187
# A: [6, 5, 4]
# B: [7, 2, 1]
# C: [8, 3]
# 188
# A: [6, 5, 4, 3]
# B: [7, 2, 1]
# C: [8]
# 189
# A: [6, 5, 4, 3]
# B: [7, 2]
# C: [8, 1]
# 190
# A: [6, 5, 4, 3, 2]
# B: [7]
# C: [8, 1]
# 191
# A: [6, 5, 4, 3, 2, 1]
# B: [7]
# C: [8]
# 192
# A: [6, 5, 4, 3, 2, 1]
# B: []
# C: [8, 7]
# 193
# A: [6, 5, 4, 3, 2]
# B: [1]
# C: [8, 7]
# 194
# A: [6, 5, 4, 3]
# B: [1]
# C: [8, 7, 2]
# 195
# A: [6, 5, 4, 3]
# B: []
# C: [8, 7, 2, 1]
# 196
# A: [6, 5, 4]
# B: [3]
# C: [8, 7, 2, 1]
# 197
# A: [6, 5, 4, 1]
# B: [3]
# C: [8, 7, 2]
# 198
# A: [6, 5, 4, 1]
# B: [3, 2]
# C: [8, 7]
# 199
# A: [6, 5, 4]
# B: [3, 2, 1]
# C: [8, 7]
# 200
# A: [6, 5]
# B: [3, 2, 1]
# C: [8, 7, 4]
# 201
# A: [6, 5]
# B: [3, 2]
# C: [8, 7, 4, 1]
# 202
# A: [6, 5, 2]
# B: [3]
# C: [8, 7, 4, 1]
# 203
# A: [6, 5, 2, 1]
# B: [3]
# C: [8, 7, 4]
# 204
# A: [6, 5, 2, 1]
# B: []
# C: [8, 7, 4, 3]
# 205
# A: [6, 5, 2]
# B: [1]
# C: [8, 7, 4, 3]
# 206
# A: [6, 5]
# B: [1]
# C: [8, 7, 4, 3, 2]
# 207
# A: [6, 5]
# B: []
# C: [8, 7, 4, 3, 2, 1]
# 208
# A: [6]
# B: [5]
# C: [8, 7, 4, 3, 2, 1]
# 209
# A: [6, 1]
# B: [5]
# C: [8, 7, 4, 3, 2]
# 210
# A: [6, 1]
# B: [5, 2]
# C: [8, 7, 4, 3]
# 211
# A: [6]
# B: [5, 2, 1]
# C: [8, 7, 4, 3]
# 212
# A: [6, 3]
# B: [5, 2, 1]
# C: [8, 7, 4]
# 213
# A: [6, 3]
# B: [5, 2]
# C: [8, 7, 4, 1]
# 214
# A: [6, 3, 2]
# B: [5]
# C: [8, 7, 4, 1]
# 215
# A: [6, 3, 2, 1]
# B: [5]
# C: [8, 7, 4]
# 216
# A: [6, 3, 2, 1]
# B: [5, 4]
# C: [8, 7]
# 217
# A: [6, 3, 2]
# B: [5, 4, 1]
# C: [8, 7]
# 218
# A: [6, 3]
# B: [5, 4, 1]
# C: [8, 7, 2]
# 219
# A: [6, 3]
# B: [5, 4]
# C: [8, 7, 2, 1]
# 220
# A: [6]
# B: [5, 4, 3]
# C: [8, 7, 2, 1]
# 221
# A: [6, 1]
# B: [5, 4, 3]
# C: [8, 7, 2]
# 222
# A: [6, 1]
# B: [5, 4, 3, 2]
# C: [8, 7]
# 223
# A: [6]
# B: [5, 4, 3, 2, 1]
# C: [8, 7]
# 224
# A: []
# B: [5, 4, 3, 2, 1]
# C: [8, 7, 6]
# 225
# A: []
# B: [5, 4, 3, 2]
# C: [8, 7, 6, 1]
# 226
# A: [2]
# B: [5, 4, 3]
# C: [8, 7, 6, 1]
# 227
# A: [2, 1]
# B: [5, 4, 3]
# C: [8, 7, 6]
# 228
# A: [2, 1]
# B: [5, 4]
# C: [8, 7, 6, 3]
# 229
# A: [2]
# B: [5, 4, 1]
# C: [8, 7, 6, 3]
# 230
# A: []
# B: [5, 4, 1]
# C: [8, 7, 6, 3, 2]
# 231
# A: []
# B: [5, 4]
# C: [8, 7, 6, 3, 2, 1]
# 232
# A: [4]
# B: [5]
# C: [8, 7, 6, 3, 2, 1]
# 233
# A: [4, 1]
# B: [5]
# C: [8, 7, 6, 3, 2]
# 234
# A: [4, 1]
# B: [5, 2]
# C: [8, 7, 6, 3]
# 235
# A: [4]
# B: [5, 2, 1]
# C: [8, 7, 6, 3]
# 236
# A: [4, 3]
# B: [5, 2, 1]
# C: [8, 7, 6]
# 237
# A: [4, 3]
# B: [5, 2]
# C: [8, 7, 6, 1]
# 238
# A: [4, 3, 2]
# B: [5]
# C: [8, 7, 6, 1]
# 239
# A: [4, 3, 2, 1]
# B: [5]
# C: [8, 7, 6]
# 240
# A: [4, 3, 2, 1]
# B: []
# C: [8, 7, 6, 5]
# 241
# A: [4, 3, 2]
# B: [1]
# C: [8, 7, 6, 5]
# 242
# A: [4, 3]
# B: [1]
# C: [8, 7, 6, 5, 2]
# 243
# A: [4, 3]
# B: []
# C: [8, 7, 6, 5, 2, 1]
# 244
# A: [4]
# B: [3]
# C: [8, 7, 6, 5, 2, 1]
# 245
# A: [4, 1]
# B: [3]
# C: [8, 7, 6, 5, 2]
# 246
# A: [4, 1]
# B: [3, 2]
# C: [8, 7, 6, 5]
# 247
# A: [4]
# B: [3, 2, 1]
# C: [8, 7, 6, 5]
# 248
# A: []
# B: [3, 2, 1]
# C: [8, 7, 6, 5, 4]
# 249
# A: []
# B: [3, 2]
# C: [8, 7, 6, 5, 4, 1]
# 250
# A: [2]
# B: [3]
# C: [8, 7, 6, 5, 4, 1]
# 251
# A: [2, 1]
# B: [3]
# C: [8, 7, 6, 5, 4]
# 252
# A: [2, 1]
# B: []
# C: [8, 7, 6, 5, 4, 3]
# 253
# A: [2]
# B: [1]
# C: [8, 7, 6, 5, 4, 3]
# 254
# A: []
# B: [1]
# C: [8, 7, 6, 5, 4, 3, 2]
# 255
# A: []
# B: []
# C: [8, 7, 6, 5, 4, 3, 2, 1]
#
#
#
#
# Generating models for 9 disks:
# Grounding for 9 disks completed in 0.1415 seconds.
